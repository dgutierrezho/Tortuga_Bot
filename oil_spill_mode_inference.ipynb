# %% [markdown]
# ## Oil Spill Model Inference
#
# **✅ IMPORTANT: Use the `idea` conda environment!**
#
# We've created a clean environment with compatible packages. To use it:
#
# 1. **Select the `idea` kernel** in the notebook:
#    - Click the kernel picker in the top-right corner of this notebook
#    - Select "Python 3.11.x (idea)" or "idea" from the list
#
# 2. **Run the cells below** - no installation needed!
#
# The `idea` environment already has:
# - TensorFlow 2.19.1
# - Protobuf 4.25.8 (compatible)
# - OpenCV, NumPy, Matplotlib, Jupyter
#
# ---
#
# **Alternative:** If you want to use your base environment, you'll need to fix multiple package conflicts, but it's **much easier to just switch to the `idea` environment**.

# %%
import numpy as np
import cv2
import tensorflow as tf
from tensorflow.keras.models import load_model

# %%
model = load_model('oil_spill_model.keras')
print("Model loaded successfully!")
# Out:
# Model loaded successfully!

# %%
labels = ['Non Oil Spill', 'Oil Spill']

def predict_image(img_path):
    img = cv2.imread(img_path)[...,::-1]  # BGR to RGB
    img = cv2.resize(img, (150, 150))
    img = img / 255.0
    img = img.reshape(1, 1, 150, 150, 3)
    
    prediction = model.predict(img)
    predicted_class = np.argmax(prediction, axis=1)[0]
    confidence = np.max(prediction) * 100
    
    return labels[predicted_class], confidence

# %%
label, confidence = predict_image('ocean.jpg')
print(f"Prediction: {label}")
print(f"Confidence: {confidence:.2f}%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Prediction: Non Oil Spill
# Confidence: 99.81%
# Prediction: Non Oil Spill
# Confidence: 99.81%
